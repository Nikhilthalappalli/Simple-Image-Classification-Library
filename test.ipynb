# %%
from Simple_Image_Classifier import Imageclassification

# %%
img_model = Imageclassification('data',epochs=25)

# %%
img_model.create_model()
# Out:
# Cleaning the images
# Cleaning is Done
# Next process is Data Collection and Data Preprocessing
# Found 462 files belonging to 3 classes.
# The classes are ['Cat', 'Dog', 'bird']
# Whole Data Size= 15, Train Size = 10, Test Size = 3, Validation Size = 1
# Process Completed
# Model Training
# Training started
# Epoch 1/25
# 10/10 [==============================] - 89s 7s/step - loss: 1.3460 - accuracy: 0.3625 - val_loss: 1.1069 - val_accuracy: 0.2396
# Epoch 2/25
# 10/10 [==============================] - 58s 5s/step - loss: 1.1012 - accuracy: 0.3187 - val_loss: 1.0790 - val_accuracy: 0.3854
# Epoch 3/25
# 10/10 [==============================] - 57s 5s/step - loss: 1.0758 - accuracy: 0.4062 - val_loss: 1.0399 - val_accuracy: 0.4479
# Epoch 4/25
# 10/10 [==============================] - 59s 5s/step - loss: 1.0381 - accuracy: 0.5125 - val_loss: 0.9322 - val_accuracy: 0.5833
# Epoch 5/25
# ...

# %%
img_model.plot_model_performance()

# %%
img_model.model_evaluation()
# Out:
# sd
# 1/1 [==============================] - 1s 1s/step
# Precision 0.9615384340286255
# Recall 1.0
# F1 Score 0.98039214256313

# %%
img_model.predict('testc.jpg')
# Out:
# 1/1 [==============================] - 0s 71ms/step
# The image belongs to Cat

# %% [markdown]
# # Because of the size of the dataset is very low and number of epochs is also low this model results may varies you can try this model with large data and more number of epochs to get a good result

# %%
img_model.model_save('image_model')
